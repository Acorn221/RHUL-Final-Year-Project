# %%
# Import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import json
import pandas as pd
import os


# define the path to the directory containing the JSON files
path = r'C:\Active-Projects\RHUL-FYP\PROJECT\Test-Train-Results\OASIS-1-Results\skin-cancer-basic-transfer-[-5]-layers-base-frozen'

# Import the JSON files
json_files = [pos_json for pos_json in os.listdir(path) if pos_json.endswith('.json')]

for file in json_files:
		with open(os.path.join(path, file)) as f:

				title = file.split('basic')[1].split('.json')[0] + ' - Transfer Learning With The Skin Cancer Dataset'
				# Create a pandas dataframe from the JSON file
				df = pd.read_json(f)
				history = df['history']
				# Plot the data
				plt.plot(history['loss'], label='loss')
				plt.plot(history['val_loss'], label='val_loss')
				plt.xlabel('Epoch')
				plt.ylabel('Loss')
				plt.title(title)
				plt.legend()
				plt.grid(True)
				plt.show()
				plt.plot(history['categorical_accuracy'], label='categorical_accuracy')
				plt.plot(history['val_categorical_accuracy'], label='val_categorical_accuracy')
				plt.xlabel('Epoch')
				plt.ylabel('Accuracy')
				plt.title(title)
				plt.legend()
				plt.grid(True)
				plt.show()

# %%
lastEpochs = -50
for file in json_files:
		with open(os.path.join(path, file)) as f:

				title = file.split('basic')[1].split('.json')[0] + ' - Transfer Learning With The Skin Cancer Dataset (last 50 epochs))'
				# Create a pandas dataframe from the JSON file
				df = pd.read_json(f)
				history = df['history']
				# Plot the data
				plt.plot(history['loss'][lastEpochs:], label='loss')
				plt.plot(history['val_loss'][lastEpochs:], label='val_loss')
				plt.xlabel('Epoch')
				plt.ylabel('Loss')
				plt.title(title)
				plt.legend()
				plt.grid(True)
				plt.show()
				plt.plot(history['categorical_accuracy'][lastEpochs:], label='categorical_accuracy')
				plt.plot(history['val_categorical_accuracy'][lastEpochs:], label='val_categorical_accuracy')
				plt.xlabel('Epoch')
				plt.ylabel('Accuracy')
				plt.title(title)
				plt.legend()
				plt.grid(True)
				plt.show()
