# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate
from tensorflow.keras.utils import Sequence

# %%
# Importing the scans from processed_scans folder, 
fileNames = []

# Create an array of all the file names from the processed_scans folder
for root, dirs, files in os.walk('processed_scans'):
	for file in files:
		fileNames.append(file)

# Importing the labels from the csv file
labels = pd.read_csv('oasis_cross-sectional.csv', dtype=str)

# %%
# Display the first image and the label for it
plt.imshow(plt.imread('processed_scans/'+fileNames[0]))
plt.show()
print(fileNames[0])
print(labels[0:1])
# Out:
# OAS1_0001_MR1.gif
#               ID M/F Hand Age Educ SES MMSE CDR  eTIV   nWBV    ASF Delay
# 0  OAS1_0001_MR1   F    R  74    2   3   29   0  1344  0.743  1.306   NaN

# %%
image_data = []

for fileName in fileNames:
    img = load_img('processed_scans/'+fileName, target_size=(224, 224, 3))
    img_array = img_to_array(img)
    image_data.append(img_array)

image_data = np.array(image_data)

# %%
# Checking to see if there's a corresponding label for each image
checkedLabels = labels[labels['ID'].isin([fileName[:13] for fileName in fileNames])]

# %%
directory='C:/Active-Projects/RHUL-FYP/PROJECT/OASIS/processed_scans/'

def createFileName(id):
	return directory + id + ".png"

# Create a new column in the labels dataframe that contains the file name
checkedLabels['fileNames'] = checkedLabels['ID'].apply(createFileName)

# CDR can be '0.0', '0.5', 'nan', '1.0', '2.0'
# As this is not a scale, but more of a classification, this can be passed as a string, then tokenized
def convertToString(cdr):
	if str(cdr) == 'nan':
		return '0'
	else:
		return str(cdr)

# Convert the CDR column to a float (if it's nan, it will be converted to 0)
checkedLabels['CDR'] = checkedLabels['CDR'].apply(convertToString)

# Creating Age_scaled column
checkedLabels['Age_scaled'] = checkedLabels['Age'].apply(lambda x: float(x) / float(checkedLabels['Age'].max()))

# Creating MMSE_scaled column

def mmseConvert(x):
	if math.isnan(float(x)):
		return np.random.randint(25, 30)
	else:
		return x

checkedLabels['MMSE'] = checkedLabels['MMSE'].apply(mmseConvert)
# Out:
# C:\Users\mlg\AppData\Local\Temp\ipykernel_29520\2951820302.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checkedLabels['fileNames'] = checkedLabels['ID'].apply(createFileName)
# C:\Users\mlg\AppData\Local\Temp\ipykernel_29520\2951820302.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checkedLabels['CDR'] = checkedLabels['CDR'].apply(convertToString)
# C:\Users\mlg\AppData\Local\Temp\ipykernel_29520\2951820302.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checkedLabels['Age_scaled'] = checkedLabels['Age'].apply(lambda x: float(x) / float(checkedLabels['Age'].max()))
# C:\Users\mlg\AppData\Local\Temp\ipykernel_29520\2951820302.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checkedLabels['MMSE'] = checkedLabels['MMSE'].apply(mmseConvert)

# %%
# Print all the unique values in the CDR column
print(checkedLabels['CDR'].unique())
print(checkedLabels['MMSE'].unique())
print(checkedLabels[[ 'M/F', 'Age', 'Educ', 'MMSE']].isna().sum())
# Out:
# ['0' '0.5' '1' '2']
# ['29' '27' 28 26 27 '30' 29 '28' '23' 25 '26' '22' '21' '15' '25' '18'
#  '24' '20' '16' '17' '19' '14']
# M/F       0
# Age       0
# Educ    201
# MMSE      0
# dtype: int64

# %%
train_datagen = ImageDataGenerator(rescale=1/255,
    validation_split=0.2,
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    height_shift_range=0.05,
    width_shift_range=0.05,
    shear_range=0.08,
    zoom_range=0.08,
    horizontal_flip=True,
    vertical_flip=False,
)

# %%
# TODO: implement the normalizer

# Import sk learn normalizer
from sklearn.preprocessing import Normalizer

# Create a normalizer
normalizer = Normalizer()

# Fit the normalizer to the training data
normalizer.fit([checkedLabels['Age'], checkedLabels['MMSE']])
# Out:
# Normalizer()

# %%
# https://medium.com/analytics-vidhya/write-your-own-custom-data-generator-for-tensorflow-keras-1252b64e41c3 For help
class CustomGenerator(Sequence):
	def __init__(self, df, datagen, batch_size, target_size):
		self.df = df
		self.datagen = datagen
		self.batch_size = batch_size
		self.target_size = target_size
			
	def __len__(self):
		return int(np.ceil(len(self.df) / self.batch_size))
	
	def on_epoch_end(self):
		pass
	
	def __getitem__(self, idx):

		# If the batch size is not a multiple of the total number of images, the last batch will be smaller
		batchEnd = (idx+1)*self.batch_size if (idx+1)*self.batch_size < len(self.df) else len(self.df)

		#print(f"batch: {idx*self.batch_size} {batchEnd}, idx: {idx}")

		# Get the batch
		batch = self.df[idx*self.batch_size:batchEnd]

		# Create the arrays to store the images and labels
		batch_x = np.zeros((len(batch),) + self.target_size + (3,), dtype='float32')
		batch_y = np.zeros((len(batch),), dtype='int32')

		# Create the arrays to store the attributes
		batch_a = np.zeros((len(batch), 4), dtype='float32')
		
		for i, row in batch.iterrows():
			try:
				# i refers to the index of the dataframe, not the batch
				currentIndex = i % self.batch_size - 1

				#print(f"i: {i}, currentIndex: {currentIndex}, batchEnd: {batchEnd}, batchStart: {idx*self.batch_size}")

				img = tf.keras.preprocessing.image.load_img(
					row['fileNames'],
					target_size=self.target_size
				)
				x = tf.keras.preprocessing.image.img_to_array(img)
				x = self.datagen.random_transform(x)
				x = self.datagen.standardize(x)

				batch_x[currentIndex] = x

				batch_y[currentIndex] = float(row['CDR'])
				batch_a[currentIndex, 0] = float(1 if row['M/F'] == 'M' else 0)
				batch_a[currentIndex, 1] = float(row['Age'])
				batch_a[currentIndex, 2] = float(row['MMSE'])
				batch_a[currentIndex, 3] = float(row['eTIV'])
			except Exception as e:
				print(f";( {e}")
			
		return ([batch_a, batch_x], batch_y)

# %%
# Setting the train/validation split
split = 0.8
splitIndex = int(len(checkedLabels) * split)

train_ds = CustomGenerator(
    checkedLabels[:splitIndex],
    train_datagen,
    batch_size=8,
    target_size=(224, 224)
)

val_ds = CustomGenerator(
    checkedLabels[splitIndex:],
    train_datagen,
    batch_size=8,
    target_size=(224, 224)
)

# %%
# Getting a batch from the generator
sample = train_ds.__getitem__(0)

# Selecting the first image from the batch
img = sample[0][1][0]

# getting the image attributes
attributes = sample[0][0][0]
print(f"M/F (0 = F, 1 = M): {attributes[0]}, Age:{attributes[1]}, MMSE Score:{attributes[2]}")

# getting the CDR value
print(f"CDR: {sample[1][0]}")

# Plotting the image
plt.imshow(img)
# Out:
# M/F (0 = F, 1 = M): 0.0, Age:55.0, MMSE Score:29.0
# CDR: 0
# c:\Users\mlg\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\preprocessing\image.py:1863: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# c:\Users\mlg\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\preprocessing\image.py:1873: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(

# %%
# Creating a sub-model to be concatenated with the main model, with age/gender/education/MMSE as input

sub_model_input = Input(shape=(4,))

x = Dense(64, activation='relu')(sub_model_input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)

sub_model_output = Dense(64, activation='relu')(x)

sub_model = Model(inputs=sub_model_input, outputs=sub_model_output)

# %%
# Here I'm using the MobileNetV2 model for testing purposes as it is a lightweight model
preTrainedModel = keras.applications.InceptionV3(
	input_shape=(224, 224, 3),
	include_top=False,
)

for _ in range(3):
	preTrainedModel.layers.pop()

# Freezing the layers of the model so that they don't get trained (apart from the last 10)
# This should help the training to not override the feature extraction layers
for layer in preTrainedModel.layers[:-5]:
	layer.trainable = False

# %%
inputs = Input(shape=(224, 224, 3))
x = preTrainedModel(inputs)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Concatenate()([sub_model.output, x])
x = Dense(512, activation='relu')(x)
outputs = Dense(4, activation='softmax')(x)

model = Model(inputs=[sub_model_input, inputs], outputs=outputs)

# The summary of the model is shown, this is to check if the model is being built correctly
model.summary()

model.compile(
	optimizer=keras.optimizers.Adam(learning_rate=0.000001),
	loss='sparse_categorical_crossentropy',
	metrics=['accuracy']
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4)]          0           []
#
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  dense (Dense)                  (None, 64)           320         ['input_1[0][0]']
#
#  inception_v3 (Functional)      (None, 5, 5, 2048)   21802784    ['input_3[0][0]']
#
#  dense_1 (Dense)                (None, 512)          33280       ['dense[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 3, 3, 64)     1179712     ['inception_v3[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_1[0][0]']
#
#  flatten (Flatten)              (None, 576)          0           ['conv2d_94[0][0]']
#
#  dense_2 (Dense)                (None, 64)           32832       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 576)          0           ['flatten[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 640)          0           ['dense_2[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_3 (Dense)                (None, 512)          328192      ['concatenate_2[0][0]']
#
#  dense_4 (Dense)                (None, 4)            2052        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 23,379,172
# Trainable params: 1,576,388
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# Fit the model to the training data
history = model.fit(
	x=train_ds,
	epochs=100,
	validation_data=val_ds,
	batch_size=8,
)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 44/44 [==============================] - 14s 111ms/step - loss: 38.7723 - accuracy: 0.0057 - val_loss: 29.1887 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 44/44 [==============================] - 3s 76ms/step - loss: 35.2509 - accuracy: 0.0086 - val_loss: 24.7793 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 44/44 [==============================] - 4s 81ms/step - loss: 30.6066 - accuracy: 0.0057 - val_loss: 20.2667 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 44/44 [==============================] - 3s 78ms/step - loss: 26.1280 - accuracy: 0.0057 - val_loss: 15.6570 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 44/44 [==============================] - 3s 74ms/step - loss: 22.0886 - accuracy: 0.0057 - val_loss: 11.2981 - val_accuracy: 0.0115
# Epoch 6/100
# 44/44 [==============================] - 3s 73ms/step - loss: 17.5035 - accuracy: 0.0345 - val_loss: 6.5883 - val_accuracy: 0.0115
# Epoch 7/100
# 44/44 [==============================] - 3s 73ms/step - loss: 13.1563 - accuracy: 0.0402 - val_loss: 2.2766 - val_accuracy: 0.2759
# Epoch 8/100
# 44/44 [==============================] - 3s 75ms/step - loss: 9.4038 - accuracy: 0.1322 - val_loss: 0.7604 - val_accuracy: 0.8161
# Epoch 9/100
# 44/44 [==============================] - 3s 73ms/step - loss: 6.5193 - accuracy: 0.2845 - val_loss: 0.8778 - val_accuracy: 0.9195
# Epoch 10/100
# 44/44 [==============================] - 3s 74ms/step - loss: 5.2098 - accuracy: 0.4224 - val_loss: 1.1449 - val_accuracy: 0.9195
# Epoch 11/100
# 44/44 [==============================] - 3s 76ms/step - loss: 3.4084 - accuracy: 0.5747 - val_loss: 1.2735 - val_accuracy: 0.9195
# Epoch 12/100
# 44/44 [==============================] - 3s 74ms/step - loss: 2.6986 - accuracy: 0.6868 - val_loss: 1.2781 - val_accuracy: 0.9195
# Epoch 13/100
# 44/44 [==============================] - 3s 73ms/step - loss: 2.3708 - accuracy: 0.7299 - val_loss: 1.2802 - val_accuracy: 0.9195
# Epoch 14/100
# 44/44 [==============================] - 3s 74ms/step - loss: 2.0395 - accuracy: 0.7414 - val_loss: 1.3966 - val_accuracy: 0.9195
# Epoch 15/100
# 44/44 [==============================] - 3s 73ms/step - loss: 1.8164 - accuracy: 0.7845 - val_loss: 1.3470 - val_accuracy: 0.9195
# Epoch 16/100
# 44/44 [==============================] - 3s 73ms/step - loss: 1.5273 - accuracy: 0.8247 - val_loss: 1.3936 - val_accuracy: 0.9195
# Epoch 17/100
# 44/44 [==============================] - 3s 73ms/step - loss: 1.8111 - accuracy: 0.8075 - val_loss: 1.4648 - val_accuracy: 0.9195
# Epoch 18/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.9023 - accuracy: 0.8075 - val_loss: 1.4255 - val_accuracy: 0.9195
# Epoch 19/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.9201 - accuracy: 0.8276 - val_loss: 1.4123 - val_accuracy: 0.9195
# Epoch 20/100
# 44/44 [==============================] - 4s 81ms/step - loss: 1.6870 - accuracy: 0.8190 - val_loss: 1.4253 - val_accuracy: 0.9195
# Epoch 21/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.5364 - accuracy: 0.8592 - val_loss: 1.3987 - val_accuracy: 0.9195
# Epoch 22/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.5909 - accuracy: 0.8563 - val_loss: 1.4049 - val_accuracy: 0.9195
# Epoch 23/100
# 44/44 [==============================] - 3s 79ms/step - loss: 1.4942 - accuracy: 0.8793 - val_loss: 1.3461 - val_accuracy: 0.9195
# Epoch 24/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.7178 - accuracy: 0.8333 - val_loss: 1.2915 - val_accuracy: 0.9195
# Epoch 25/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.3074 - accuracy: 0.8678 - val_loss: 1.2541 - val_accuracy: 0.9195
# Epoch 26/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.6264 - accuracy: 0.8190 - val_loss: 1.2933 - val_accuracy: 0.9195
# Epoch 27/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.5407 - accuracy: 0.8477 - val_loss: 1.2594 - val_accuracy: 0.9195
# Epoch 28/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.5377 - accuracy: 0.8563 - val_loss: 1.2817 - val_accuracy: 0.9195
# Epoch 29/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.5265 - accuracy: 0.8707 - val_loss: 1.2640 - val_accuracy: 0.9195
# Epoch 30/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1463 - accuracy: 0.8707 - val_loss: 1.1867 - val_accuracy: 0.9195
# Epoch 31/100
# 44/44 [==============================] - 4s 81ms/step - loss: 1.5716 - accuracy: 0.8448 - val_loss: 1.1924 - val_accuracy: 0.9195
# Epoch 32/100
# 44/44 [==============================] - 4s 82ms/step - loss: 1.2637 - accuracy: 0.8448 - val_loss: 1.3045 - val_accuracy: 0.9195
# Epoch 33/100
# 44/44 [==============================] - 4s 79ms/step - loss: 1.4704 - accuracy: 0.8764 - val_loss: 1.1962 - val_accuracy: 0.9195
# Epoch 34/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.4839 - accuracy: 0.8707 - val_loss: 1.1751 - val_accuracy: 0.9195
# Epoch 35/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.5611 - accuracy: 0.8506 - val_loss: 1.1943 - val_accuracy: 0.9195
# Epoch 36/100
# 44/44 [==============================] - 3s 75ms/step - loss: 1.4750 - accuracy: 0.8563 - val_loss: 1.2433 - val_accuracy: 0.9195
# Epoch 37/100
# 44/44 [==============================] - 3s 75ms/step - loss: 1.5242 - accuracy: 0.8678 - val_loss: 1.2357 - val_accuracy: 0.9195
# Epoch 38/100
# 44/44 [==============================] - 3s 75ms/step - loss: 1.5176 - accuracy: 0.8908 - val_loss: 1.1828 - val_accuracy: 0.9195
# Epoch 39/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.2538 - accuracy: 0.8879 - val_loss: 1.0934 - val_accuracy: 0.9195
# Epoch 40/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.3825 - accuracy: 0.8649 - val_loss: 1.1559 - val_accuracy: 0.9195
# Epoch 41/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.4848 - accuracy: 0.8736 - val_loss: 1.1002 - val_accuracy: 0.9195
# Epoch 42/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.3444 - accuracy: 0.8506 - val_loss: 1.1412 - val_accuracy: 0.9195
# Epoch 43/100
# 44/44 [==============================] - 3s 73ms/step - loss: 1.7559 - accuracy: 0.8736 - val_loss: 1.1565 - val_accuracy: 0.9195
# Epoch 44/100
# 44/44 [==============================] - 3s 75ms/step - loss: 1.3937 - accuracy: 0.8764 - val_loss: 1.1120 - val_accuracy: 0.9195
# Epoch 45/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.5010 - accuracy: 0.8592 - val_loss: 1.1452 - val_accuracy: 0.9195
# Epoch 46/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.3337 - accuracy: 0.8592 - val_loss: 1.0684 - val_accuracy: 0.9195
# Epoch 47/100
# 44/44 [==============================] - 4s 87ms/step - loss: 1.1552 - accuracy: 0.8908 - val_loss: 1.0205 - val_accuracy: 0.9195
# Epoch 48/100
# 44/44 [==============================] - 4s 83ms/step - loss: 1.2545 - accuracy: 0.8649 - val_loss: 1.0838 - val_accuracy: 0.9195
# Epoch 49/100
# 44/44 [==============================] - 4s 100ms/step - loss: 1.2409 - accuracy: 0.9023 - val_loss: 1.0340 - val_accuracy: 0.9195
# Epoch 50/100
# 44/44 [==============================] - 4s 94ms/step - loss: 1.4405 - accuracy: 0.8563 - val_loss: 1.0227 - val_accuracy: 0.9195
# Epoch 51/100
# 44/44 [==============================] - 3s 79ms/step - loss: 1.1606 - accuracy: 0.8822 - val_loss: 1.0158 - val_accuracy: 0.9195
# Epoch 52/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.2918 - accuracy: 0.8678 - val_loss: 0.9533 - val_accuracy: 0.9195
# Epoch 53/100
# 44/44 [==============================] - 4s 82ms/step - loss: 0.9323 - accuracy: 0.8966 - val_loss: 0.9808 - val_accuracy: 0.9195
# Epoch 54/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.2769 - accuracy: 0.8822 - val_loss: 1.0171 - val_accuracy: 0.9195
# Epoch 55/100
# 44/44 [==============================] - 3s 79ms/step - loss: 1.2455 - accuracy: 0.8736 - val_loss: 0.9809 - val_accuracy: 0.9195
# Epoch 56/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1552 - accuracy: 0.8937 - val_loss: 0.9581 - val_accuracy: 0.9195
# Epoch 57/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1968 - accuracy: 0.8621 - val_loss: 1.0008 - val_accuracy: 0.9195
# Epoch 58/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1241 - accuracy: 0.8793 - val_loss: 0.9906 - val_accuracy: 0.9195
# Epoch 59/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.0888 - accuracy: 0.8879 - val_loss: 1.0071 - val_accuracy: 0.9195
# Epoch 60/100
# 44/44 [==============================] - 3s 76ms/step - loss: 1.1570 - accuracy: 0.8908 - val_loss: 0.9399 - val_accuracy: 0.9195
# Epoch 61/100
# 44/44 [==============================] - 3s 79ms/step - loss: 0.9560 - accuracy: 0.9023 - val_loss: 0.9402 - val_accuracy: 0.9195
# Epoch 62/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.1112 - accuracy: 0.8506 - val_loss: 0.9922 - val_accuracy: 0.9195
# Epoch 63/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.0929 - accuracy: 0.8937 - val_loss: 0.9131 - val_accuracy: 0.9195
# Epoch 64/100
# 44/44 [==============================] - 4s 82ms/step - loss: 1.2238 - accuracy: 0.8908 - val_loss: 0.8635 - val_accuracy: 0.9195
# Epoch 65/100
# 44/44 [==============================] - 3s 79ms/step - loss: 1.0384 - accuracy: 0.8764 - val_loss: 0.9419 - val_accuracy: 0.9195
# Epoch 66/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.2620 - accuracy: 0.8678 - val_loss: 0.8825 - val_accuracy: 0.9195
# Epoch 67/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1653 - accuracy: 0.8678 - val_loss: 0.9736 - val_accuracy: 0.9195
# Epoch 68/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.1068 - accuracy: 0.8822 - val_loss: 0.9935 - val_accuracy: 0.9195
# Epoch 69/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.2970 - accuracy: 0.8764 - val_loss: 0.9082 - val_accuracy: 0.9195
# Epoch 70/100
# 44/44 [==============================] - 3s 79ms/step - loss: 1.4363 - accuracy: 0.8793 - val_loss: 0.9353 - val_accuracy: 0.9195
# Epoch 71/100
# 44/44 [==============================] - 4s 79ms/step - loss: 1.1057 - accuracy: 0.8879 - val_loss: 0.9176 - val_accuracy: 0.9195
# Epoch 72/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1284 - accuracy: 0.8649 - val_loss: 0.9162 - val_accuracy: 0.9195
# Epoch 73/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.0526 - accuracy: 0.8937 - val_loss: 0.9425 - val_accuracy: 0.9195
# Epoch 74/100
# 44/44 [==============================] - 4s 82ms/step - loss: 1.0386 - accuracy: 0.8707 - val_loss: 0.8935 - val_accuracy: 0.9195
# Epoch 75/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.1141 - accuracy: 0.8908 - val_loss: 0.8559 - val_accuracy: 0.9195
# Epoch 76/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.0346 - accuracy: 0.8592 - val_loss: 0.8914 - val_accuracy: 0.9195
# Epoch 77/100
# 44/44 [==============================] - 3s 79ms/step - loss: 0.9652 - accuracy: 0.8966 - val_loss: 0.8682 - val_accuracy: 0.9195
# Epoch 78/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.2043 - accuracy: 0.8937 - val_loss: 0.7980 - val_accuracy: 0.9195
# Epoch 79/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1409 - accuracy: 0.8764 - val_loss: 0.8219 - val_accuracy: 0.9195
# Epoch 80/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.0613 - accuracy: 0.8822 - val_loss: 0.8113 - val_accuracy: 0.9195
# Epoch 81/100
# 44/44 [==============================] - 3s 79ms/step - loss: 0.9852 - accuracy: 0.8908 - val_loss: 0.7392 - val_accuracy: 0.9195
# Epoch 82/100
# 44/44 [==============================] - 3s 78ms/step - loss: 0.8440 - accuracy: 0.8879 - val_loss: 0.8136 - val_accuracy: 0.9195
# Epoch 83/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.1125 - accuracy: 0.8621 - val_loss: 0.7518 - val_accuracy: 0.9195
# Epoch 84/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.0881 - accuracy: 0.8707 - val_loss: 0.8721 - val_accuracy: 0.9195
# Epoch 85/100
# 44/44 [==============================] - 3s 78ms/step - loss: 0.7834 - accuracy: 0.9138 - val_loss: 0.7694 - val_accuracy: 0.9195
# Epoch 86/100
# 44/44 [==============================] - 4s 85ms/step - loss: 1.0752 - accuracy: 0.8707 - val_loss: 0.8553 - val_accuracy: 0.9195
# Epoch 87/100
# 44/44 [==============================] - 4s 83ms/step - loss: 1.0209 - accuracy: 0.8707 - val_loss: 0.7892 - val_accuracy: 0.9195
# Epoch 88/100
# 44/44 [==============================] - 3s 78ms/step - loss: 1.0131 - accuracy: 0.8822 - val_loss: 0.7736 - val_accuracy: 0.9195
# Epoch 89/100
# 44/44 [==============================] - 4s 83ms/step - loss: 1.0228 - accuracy: 0.8851 - val_loss: 0.7617 - val_accuracy: 0.9195
# Epoch 90/100
# 44/44 [==============================] - 3s 79ms/step - loss: 1.1279 - accuracy: 0.8649 - val_loss: 0.8022 - val_accuracy: 0.9195
# Epoch 91/100
# 44/44 [==============================] - 4s 88ms/step - loss: 1.0722 - accuracy: 0.8937 - val_loss: 0.7953 - val_accuracy: 0.9195
# Epoch 92/100
# 44/44 [==============================] - 4s 83ms/step - loss: 1.1841 - accuracy: 0.8822 - val_loss: 0.6946 - val_accuracy: 0.9195
# Epoch 93/100
# 44/44 [==============================] - 4s 81ms/step - loss: 0.8440 - accuracy: 0.8908 - val_loss: 0.7164 - val_accuracy: 0.9195
# Epoch 94/100
# 44/44 [==============================] - 4s 83ms/step - loss: 0.9896 - accuracy: 0.8707 - val_loss: 0.7520 - val_accuracy: 0.9195
# Epoch 95/100
# 44/44 [==============================] - 3s 78ms/step - loss: 0.9306 - accuracy: 0.8994 - val_loss: 0.7376 - val_accuracy: 0.9195
# Epoch 96/100
# 44/44 [==============================] - 3s 78ms/step - loss: 0.9441 - accuracy: 0.8908 - val_loss: 0.6992 - val_accuracy: 0.9195
# Epoch 97/100
# 44/44 [==============================] - 3s 77ms/step - loss: 1.1086 - accuracy: 0.8879 - val_loss: 0.7104 - val_accuracy: 0.9195
# Epoch 98/100
# 44/44 [==============================] - 3s 78ms/step - loss: 0.6574 - accuracy: 0.9052 - val_loss: 0.6503 - val_accuracy: 0.9195
# Epoch 99/100
# 44/44 [==============================] - 3s 77ms/step - loss: 0.9937 - accuracy: 0.8879 - val_loss: 0.6406 - val_accuracy: 0.9195
# Epoch 100/100
# 44/44 [==============================] - 3s 78ms/step - loss: 0.9502 - accuracy: 0.8822 - val_loss: 0.6686 - val_accuracy: 0.9195

# %%
# Unfreeze all the layers of the model
for layer in model.layers:
	layer.trainable = True

# Compile the model again, with a slower learning rate

model.compile(
	optimizer=keras.optimizers.Adam(learning_rate=0.0000001),
	loss='sparse_categorical_crossentropy',
	metrics=['accuracy']
)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4)]          0           []
#
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  dense (Dense)                  (None, 64)           320         ['input_1[0][0]']
#
#  inception_v3 (Functional)      (None, 5, 5, 2048)   21802784    ['input_3[0][0]']
#
#  dense_1 (Dense)                (None, 512)          33280       ['dense[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 3, 3, 64)     1179712     ['inception_v3[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_1[0][0]']
#
#  flatten (Flatten)              (None, 576)          0           ['conv2d_94[0][0]']
#
#  dense_2 (Dense)                (None, 64)           32832       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 576)          0           ['flatten[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 640)          0           ['dense_2[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_3 (Dense)                (None, 512)          328192      ['concatenate_2[0][0]']
#
#  dense_4 (Dense)                (None, 4)            2052        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 23,379,172
# Trainable params: 23,344,740
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# Fit the model to the training data
fine_tuning_history = model.fit(
	x=train_ds,
	epochs=100,
	validation_data=val_ds,
	batch_size=8,
)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 11s 113ms/step - loss: 1.7297 - accuracy: 0.6724 - val_loss: 0.6092 - val_accuracy: 0.9195
# Epoch 2/100
# 44/44 [==============================] - 4s 82ms/step - loss: 1.9380 - accuracy: 0.6810 - val_loss: 0.7590 - val_accuracy: 0.9195
# Epoch 3/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.7124 - accuracy: 0.6897 - val_loss: 0.6925 - val_accuracy: 0.9195
# Epoch 4/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.7849 - accuracy: 0.7069 - val_loss: 0.6372 - val_accuracy: 0.9195
# Epoch 5/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.4446 - accuracy: 0.7213 - val_loss: 0.6670 - val_accuracy: 0.9195
# Epoch 6/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.4727 - accuracy: 0.7414 - val_loss: 0.6595 - val_accuracy: 0.9195
# Epoch 7/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.5044 - accuracy: 0.7040 - val_loss: 0.6666 - val_accuracy: 0.9195
# Epoch 8/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.3242 - accuracy: 0.7443 - val_loss: 0.6076 - val_accuracy: 0.9195
# Epoch 9/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.7472 - accuracy: 0.7241 - val_loss: 0.6835 - val_accuracy: 0.9195
# Epoch 10/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.6050 - accuracy: 0.7644 - val_loss: 0.6094 - val_accuracy: 0.9195
# Epoch 11/100
# 44/44 [==============================] - 4s 79ms/step - loss: 1.2913 - accuracy: 0.7845 - val_loss: 0.6415 - val_accuracy: 0.9195
# Epoch 12/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.3152 - accuracy: 0.7989 - val_loss: 0.7277 - val_accuracy: 0.9195
# Epoch 13/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.7292 - accuracy: 0.7615 - val_loss: 0.7740 - val_accuracy: 0.9195
# Epoch 14/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.3238 - accuracy: 0.7902 - val_loss: 0.7235 - val_accuracy: 0.9195
# Epoch 15/100
# 44/44 [==============================] - 4s 81ms/step - loss: 1.5773 - accuracy: 0.7759 - val_loss: 0.7253 - val_accuracy: 0.9195
# Epoch 16/100
# 44/44 [==============================] - 4s 80ms/step - loss: 1.3852 - accuracy: 0.7960 - val_loss: 0.7677 - val_accuracy: 0.9195
# Epoch 17/100
# 44/44 [==============================] - 4s 81ms/step - loss: 1.2391 - accuracy: 0.8161 - val_loss: 0.7276 - val_accuracy: 0.9195
# Epoch 18/100
# 44/44 [==============================] - 4s 81ms/step - loss: 1.3173 - accuracy: 0.8218 - val_loss: 0.7262 - val_accuracy: 0.9195
# Epoch 19/100
# 44/44 [==============================] - 4s 81ms/step - loss: 1.3532 - accuracy: 0.7989 - val_loss: 0.8264 - val_accuracy: 0.9195
# Epoch 20/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.1545 - accuracy: 0.8190 - val_loss: 0.7959 - val_accuracy: 0.9195
# Epoch 21/100
# 44/44 [==============================] - 4s 85ms/step - loss: 1.4655 - accuracy: 0.8046 - val_loss: 0.8532 - val_accuracy: 0.9195
# Epoch 22/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.3679 - accuracy: 0.8132 - val_loss: 0.8476 - val_accuracy: 0.9195
# Epoch 23/100
# 44/44 [==============================] - 4s 85ms/step - loss: 1.3810 - accuracy: 0.7960 - val_loss: 0.8663 - val_accuracy: 0.9195
# Epoch 24/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.4193 - accuracy: 0.8017 - val_loss: 0.7449 - val_accuracy: 0.9195
# Epoch 25/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.1918 - accuracy: 0.8218 - val_loss: 0.7820 - val_accuracy: 0.9195
# Epoch 26/100
# 44/44 [==============================] - 4s 87ms/step - loss: 1.4532 - accuracy: 0.7989 - val_loss: 0.8509 - val_accuracy: 0.9195
# Epoch 27/100
# 44/44 [==============================] - 14s 165ms/step - loss: 1.3643 - accuracy: 0.8333 - val_loss: 0.8516 - val_accuracy: 0.9195
# Epoch 28/100
# 44/44 [==============================] - 7s 152ms/step - loss: 1.0502 - accuracy: 0.8305 - val_loss: 0.8539 - val_accuracy: 0.9195
# Epoch 29/100
# 44/44 [==============================] - 4s 91ms/step - loss: 1.1592 - accuracy: 0.8305 - val_loss: 0.9585 - val_accuracy: 0.9195
# Epoch 30/100
# 44/44 [==============================] - 4s 96ms/step - loss: 1.5216 - accuracy: 0.8046 - val_loss: 0.8618 - val_accuracy: 0.9195
# Epoch 31/100
# 44/44 [==============================] - 6s 144ms/step - loss: 1.3628 - accuracy: 0.8276 - val_loss: 0.9549 - val_accuracy: 0.9195
# Epoch 32/100
# 44/44 [==============================] - 8s 178ms/step - loss: 1.3827 - accuracy: 0.8161 - val_loss: 0.8342 - val_accuracy: 0.9195
# Epoch 33/100
# 44/44 [==============================] - 7s 152ms/step - loss: 1.1830 - accuracy: 0.8420 - val_loss: 0.8669 - val_accuracy: 0.9195
# Epoch 34/100
# 44/44 [==============================] - 9s 210ms/step - loss: 1.1635 - accuracy: 0.8305 - val_loss: 0.8914 - val_accuracy: 0.9195
# Epoch 35/100
# 44/44 [==============================] - 4s 86ms/step - loss: 1.0246 - accuracy: 0.8190 - val_loss: 0.9013 - val_accuracy: 0.9195
# Epoch 36/100
# 44/44 [==============================] - 4s 91ms/step - loss: 1.3338 - accuracy: 0.8448 - val_loss: 0.8910 - val_accuracy: 0.9195
# Epoch 37/100
# 44/44 [==============================] - 4s 95ms/step - loss: 1.0760 - accuracy: 0.8534 - val_loss: 0.9207 - val_accuracy: 0.9195
# Epoch 38/100
# 44/44 [==============================] - 5s 124ms/step - loss: 1.0687 - accuracy: 0.8707 - val_loss: 0.9363 - val_accuracy: 0.9195
# Epoch 39/100
# 44/44 [==============================] - 4s 87ms/step - loss: 1.0350 - accuracy: 0.8649 - val_loss: 0.9807 - val_accuracy: 0.9195
# Epoch 40/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.2289 - accuracy: 0.8649 - val_loss: 0.8524 - val_accuracy: 0.9195
# Epoch 41/100
# 44/44 [==============================] - 5s 113ms/step - loss: 1.2729 - accuracy: 0.8534 - val_loss: 0.9075 - val_accuracy: 0.9195
# Epoch 42/100
# 44/44 [==============================] - 4s 90ms/step - loss: 1.1705 - accuracy: 0.8477 - val_loss: 0.9521 - val_accuracy: 0.9195
# Epoch 43/100
# 44/44 [==============================] - 5s 105ms/step - loss: 1.1970 - accuracy: 0.8477 - val_loss: 0.9395 - val_accuracy: 0.9195
# Epoch 44/100
# 44/44 [==============================] - 4s 90ms/step - loss: 1.4664 - accuracy: 0.8563 - val_loss: 0.9002 - val_accuracy: 0.9195
# Epoch 45/100
# 44/44 [==============================] - 4s 86ms/step - loss: 1.2927 - accuracy: 0.8534 - val_loss: 0.9141 - val_accuracy: 0.9195
# Epoch 46/100
# 44/44 [==============================] - 4s 87ms/step - loss: 1.1315 - accuracy: 0.8362 - val_loss: 0.9282 - val_accuracy: 0.9195
# Epoch 47/100
# 44/44 [==============================] - 4s 85ms/step - loss: 1.1012 - accuracy: 0.8736 - val_loss: 1.0023 - val_accuracy: 0.9195
# Epoch 48/100
# 44/44 [==============================] - 4s 86ms/step - loss: 1.2465 - accuracy: 0.8362 - val_loss: 0.9946 - val_accuracy: 0.9195
# Epoch 49/100
# 44/44 [==============================] - 4s 91ms/step - loss: 1.2652 - accuracy: 0.8420 - val_loss: 0.9302 - val_accuracy: 0.9195
# Epoch 50/100
# 44/44 [==============================] - 4s 86ms/step - loss: 1.1516 - accuracy: 0.8621 - val_loss: 0.9299 - val_accuracy: 0.9195
# Epoch 51/100
# 44/44 [==============================] - 4s 89ms/step - loss: 1.1499 - accuracy: 0.8707 - val_loss: 0.8941 - val_accuracy: 0.9195
# Epoch 52/100
# 44/44 [==============================] - 4s 89ms/step - loss: 1.1496 - accuracy: 0.8764 - val_loss: 0.8754 - val_accuracy: 0.9195
# Epoch 53/100
# 44/44 [==============================] - 6s 129ms/step - loss: 1.2549 - accuracy: 0.8621 - val_loss: 0.8904 - val_accuracy: 0.9195
# Epoch 54/100
# 44/44 [==============================] - 7s 155ms/step - loss: 1.0570 - accuracy: 0.8534 - val_loss: 0.9191 - val_accuracy: 0.9195
# Epoch 55/100
# 44/44 [==============================] - 6s 137ms/step - loss: 1.1422 - accuracy: 0.8534 - val_loss: 0.9869 - val_accuracy: 0.9195
# Epoch 56/100
# 44/44 [==============================] - 6s 146ms/step - loss: 1.2407 - accuracy: 0.8736 - val_loss: 0.8980 - val_accuracy: 0.9195
# Epoch 57/100
# 44/44 [==============================] - 5s 117ms/step - loss: 1.1308 - accuracy: 0.8563 - val_loss: 0.9832 - val_accuracy: 0.9195
# Epoch 58/100
# 44/44 [==============================] - 4s 85ms/step - loss: 1.1850 - accuracy: 0.8391 - val_loss: 0.9748 - val_accuracy: 0.9195
# Epoch 59/100
# 44/44 [==============================] - 6s 128ms/step - loss: 1.1693 - accuracy: 0.8793 - val_loss: 0.9505 - val_accuracy: 0.9195
# Epoch 60/100
# 44/44 [==============================] - 4s 101ms/step - loss: 1.0492 - accuracy: 0.8736 - val_loss: 0.9412 - val_accuracy: 0.9195
# Epoch 61/100
# 44/44 [==============================] - 4s 86ms/step - loss: 1.1390 - accuracy: 0.8649 - val_loss: 0.8814 - val_accuracy: 0.9195
# Epoch 62/100
# 44/44 [==============================] - 4s 98ms/step - loss: 0.9772 - accuracy: 0.8764 - val_loss: 0.9510 - val_accuracy: 0.9195
# Epoch 63/100
# 44/44 [==============================] - 6s 135ms/step - loss: 1.0555 - accuracy: 0.8736 - val_loss: 0.9610 - val_accuracy: 0.9195
# Epoch 64/100
# 44/44 [==============================] - 4s 89ms/step - loss: 1.1614 - accuracy: 0.8621 - val_loss: 0.9496 - val_accuracy: 0.9195
# Epoch 65/100
# 44/44 [==============================] - 4s 97ms/step - loss: 1.1384 - accuracy: 0.8420 - val_loss: 0.9455 - val_accuracy: 0.9195
# Epoch 66/100
# 44/44 [==============================] - 5s 108ms/step - loss: 1.2468 - accuracy: 0.8506 - val_loss: 0.8777 - val_accuracy: 0.9195
# Epoch 67/100
# 44/44 [==============================] - 4s 94ms/step - loss: 0.9863 - accuracy: 0.8937 - val_loss: 0.9565 - val_accuracy: 0.9195
# Epoch 68/100
# 44/44 [==============================] - 4s 99ms/step - loss: 1.0308 - accuracy: 0.8764 - val_loss: 1.0265 - val_accuracy: 0.9195
# Epoch 69/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.2326 - accuracy: 0.8592 - val_loss: 0.9367 - val_accuracy: 0.9195
# Epoch 70/100
# 44/44 [==============================] - 4s 84ms/step - loss: 0.9309 - accuracy: 0.8678 - val_loss: 0.8904 - val_accuracy: 0.9195
# Epoch 71/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.1247 - accuracy: 0.8764 - val_loss: 0.9811 - val_accuracy: 0.9195
# Epoch 72/100
# 44/44 [==============================] - 4s 84ms/step - loss: 1.0942 - accuracy: 0.8649 - val_loss: 1.0017 - val_accuracy: 0.9195
# Epoch 73/100
# 44/44 [==============================] - 4s 85ms/step - loss: 0.9972 - accuracy: 0.8851 - val_loss: 0.9651 - val_accuracy: 0.9195
# Epoch 74/100
# 44/44 [==============================] - 4s 82ms/step - loss: 1.2091 - accuracy: 0.8736 - val_loss: 0.9585 - val_accuracy: 0.9195
# Epoch 75/100
# 44/44 [==============================] - 4s 85ms/step - loss: 1.0124 - accuracy: 0.8678 - val_loss: 0.9147 - val_accuracy: 0.9195
# Epoch 76/100
# 44/44 [==============================] - 4s 83ms/step - loss: 1.4117 - accuracy: 0.8391 - val_loss: 0.9160 - val_accuracy: 0.9195
# Epoch 77/100
# 44/44 [==============================] - 5s 116ms/step - loss: 1.1150 - accuracy: 0.8534 - val_loss: 0.9539 - val_accuracy: 0.9195
# Epoch 78/100
# 44/44 [==============================] - 5s 120ms/step - loss: 1.2084 - accuracy: 0.8592 - val_loss: 0.8485 - val_accuracy: 0.9195
# Epoch 79/100
# 44/44 [==============================] - 7s 156ms/step - loss: 1.2120 - accuracy: 0.8879 - val_loss: 0.9437 - val_accuracy: 0.9195
# Epoch 80/100
# 44/44 [==============================] - 10s 219ms/step - loss: 1.0780 - accuracy: 0.8822 - val_loss: 0.9274 - val_accuracy: 0.9195
# Epoch 81/100
# 44/44 [==============================] - 7s 164ms/step - loss: 1.1505 - accuracy: 0.8822 - val_loss: 0.9219 - val_accuracy: 0.9195
# Epoch 82/100
# 44/44 [==============================] - 9s 197ms/step - loss: 1.0620 - accuracy: 0.8764 - val_loss: 1.0284 - val_accuracy: 0.9195
# Epoch 83/100
# 44/44 [==============================] - 8s 187ms/step - loss: 0.8290 - accuracy: 0.8793 - val_loss: 0.9400 - val_accuracy: 0.9195
# Epoch 84/100
# 44/44 [==============================] - 15s 339ms/step - loss: 1.2250 - accuracy: 0.8793 - val_loss: 0.9528 - val_accuracy: 0.9195
# Epoch 85/100
# 44/44 [==============================] - 11s 255ms/step - loss: 1.1264 - accuracy: 0.8879 - val_loss: 0.9247 - val_accuracy: 0.9195
# Epoch 86/100
# 44/44 [==============================] - 10s 223ms/step - loss: 1.2507 - accuracy: 0.8649 - val_loss: 0.9359 - val_accuracy: 0.9195
# Epoch 87/100
# 44/44 [==============================] - 6s 135ms/step - loss: 0.9532 - accuracy: 0.8736 - val_loss: 0.9285 - val_accuracy: 0.9195
# Epoch 88/100
# 44/44 [==============================] - 20s 461ms/step - loss: 1.3625 - accuracy: 0.8678 - val_loss: 0.9462 - val_accuracy: 0.9195
# Epoch 89/100
# 44/44 [==============================] - 6s 146ms/step - loss: 1.2233 - accuracy: 0.8563 - val_loss: 0.8763 - val_accuracy: 0.9195
# Epoch 90/100
# 44/44 [==============================] - 12s 283ms/step - loss: 1.0414 - accuracy: 0.8966 - val_loss: 0.8674 - val_accuracy: 0.9195
# Epoch 91/100
# 44/44 [==============================] - 4s 89ms/step - loss: 1.1719 - accuracy: 0.8793 - val_loss: 0.9167 - val_accuracy: 0.9195
# Epoch 92/100
# 44/44 [==============================] - 4s 85ms/step - loss: 0.9934 - accuracy: 0.8822 - val_loss: 0.8705 - val_accuracy: 0.9195
# Epoch 93/100
# 44/44 [==============================] - 5s 102ms/step - loss: 1.0018 - accuracy: 0.8793 - val_loss: 0.9265 - val_accuracy: 0.9195
# Epoch 94/100
# 44/44 [==============================] - 4s 91ms/step - loss: 0.8578 - accuracy: 0.8764 - val_loss: 0.8854 - val_accuracy: 0.9195
# Epoch 95/100
# 44/44 [==============================] - 4s 97ms/step - loss: 1.0222 - accuracy: 0.8994 - val_loss: 0.9072 - val_accuracy: 0.9195
# Epoch 96/100
# 44/44 [==============================] - 4s 88ms/step - loss: 1.1592 - accuracy: 0.8649 - val_loss: 0.8764 - val_accuracy: 0.9195
# Epoch 97/100
# 44/44 [==============================] - 4s 87ms/step - loss: 1.1687 - accuracy: 0.8822 - val_loss: 0.8359 - val_accuracy: 0.9195
# Epoch 98/100
# 44/44 [==============================] - 4s 88ms/step - loss: 1.2105 - accuracy: 0.8678 - val_loss: 0.8818 - val_accuracy: 0.9195
# Epoch 99/100
# 44/44 [==============================] - 4s 93ms/step - loss: 1.0155 - accuracy: 0.8764 - val_loss: 0.8602 - val_accuracy: 0.9195
# Epoch 100/100
# 44/44 [==============================] - 4s 86ms/step - loss: 0.9793 - accuracy: 0.9023 - val_loss: 0.8962 - val_accuracy: 0.9195

# %%
# Plot the training and validation loss
plt.plot(fine_tuning_history.history['loss'], label='loss')
plt.plot(fine_tuning_history.history['val_loss'], label='val_loss')
plt.plot(fine_tuning_history.history['accuracy'], label='accuracy')
plt.plot(fine_tuning_history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()
